// %%
import java.io.File

val menuFile = File("menu-file.txt")
menuFile.setReadable(true)
menuFile.setWritable(true)
menuFile.setExecutable(false)


val menuFile2 = File("menu-file.txt").apply {
     setReadable(true)
     setWritable(true)
     setExecutable(false)
}

// %%
val firstElemnet = listOf(1, 2, 3).first()
val firstItemSquared = firstElemnet * firstElemnet

val firstItemSquared2 = listOf(1, 2, 3).first().let {
    it * it
}

fun formatGreeting(vipGuest: String?): String {
    return vipGuest?.let {
        "Hello, $it!"
    } ?: "Hello, Guest!"
}

// %%
import java.io.File

val menuFile = File("menu-file.txt")
val servesDragonsBreath = menuFile.run {
    readText().contains("Dragon's Breath")
}

fun nameIsLong(name: String) = name.length >= 20
"Madrigal".run(::nameIsLong) // False
"Polarcubis, Supreme Master of NyetHack".run(::nameIsLong) // true


val status = run {
    if (menuFile.exists()) "File exists" else "File does not exist"
}

// %%
val nameTooLong = with("Madrigal") {
    length >= 20
}
