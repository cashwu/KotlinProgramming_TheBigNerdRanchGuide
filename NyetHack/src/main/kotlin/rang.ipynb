// %%
1 in 1..
// Out:
// true

// %%
(1..3).toList()
// Out:
// [1, 2, 3]

// %%
1 in 3 downTo 1
// Out:
// true

// %%
1 in 1 until 3
// Out:
// true

// %%
3 in 1 until 3
// Out:
// false

// %%
2 in 1..3
// Out:
// true

// %%
2 !in 1..3
// Out:
// false

// %%
'x' in 'a'..'z'
// Out:
// true

// %%
(1..5 step 2).toList()
// Out:
// [1, 3, 5]
